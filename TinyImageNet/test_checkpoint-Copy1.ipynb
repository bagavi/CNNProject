-- %%
require 'Utils'
require 'nngraph';
require 'loadcaffe'
require 'image'
require 'VGG'
require 'optim'
require 'Net2'


dtype = 'torch.DoubleTensor'

-- %%
local im_batch = get_validation_batch(16)
local x = torch.Tensor(im_batch:size()[1],im_batch:size()[2],224,224)

for i=1,im_batch:size()[1] do
    x[i] = preprocess(im_batch[i])
end
local uv_images, y_images = create_yuv_images(im_batch,56,56)
local x, uv_images = x:type(dtype), uv_images:type(dtype)
local y = uv_images*2

checkpoint_1 = torch.load('../../results/checkpoint_class_2000.t7')
model1 = checkpoint_1.model
model1:evaluate()
local scores1 = model1:forward(x)
local val_loss1 = crit:forward(scores1, y)
print(val_loss1)
uv_op_load1 = model1.output/2

model1 = nil

checkpoint_2 = torch.load('../../arxiv/all_classes_16_3_MSE.t7')
model2 = checkpoint_2.model
model2:evaluate()
local scores2 = model2:forward(x)
local val_loss2 = crit:forward(scores2, y)
print(val_loss2)
uv_op_load2 = model1.output/2

for i = 1,16 do
    size = 64
    itorch.image({image.scale(y2rgb(image.rgb2y(im_batch[i])),size,size),
                  image.scale(image.yuv2rgb(torch.cat(y_images[i],uv_op_load1[i],1)),size,size),
                  image.scale(image.yuv2rgb(torch.cat(y_images[i],uv_op_load2[i],1)),size,size),
                  image.scale(image.yuv2rgb(torch.cat(y_images[i],uv_images[i],1)),size,size)})
end

-- %%
local im_batch = get_validation_batch(16)
for i = 1,16 do
    size = 112
    itorch.image({image.scale(y2rgb(image.rgb2y(im_batch[i])),size,size),
                  image.scale(image.yuv2rgb(torch.cat(y_images[i],uv_op_load[i],1)),size,size),
                  image.scale(image.yuv2rgb(torch.cat(y_images[i],uv_images[i],1)),size,size)})
end
-- Out:
-- Console does not support images
-- Console does not support images
-- Console does not support images
-- Console does not support images
-- Console does not support images
-- Console does not support images
-- Console does not support images
-- Console does not support images
-- Console does not support images
-- Console does not support images
-- Console does not support images
-- Console does not support images
-- Console does not support images
-- Console does not support images
-- Console does not support images
-- Console does not support images

-- %%
collectgarbage()
checkpoint_1 = torch.load('../../results/checkpoint_80.t7')
model = checkpoint_1.model
local crit = nn.MSECriterion():type(dtype)
opt = checkpoint_1.opt
model:evaluate()

local im_batch = get_validation_batch(4)
local x = torch.Tensor(im_batch:size()[1],im_batch:size()[2],224,224)

for i=1,im_batch:size()[1] do
    x[i] = preprocess(im_batch[i])
end
local uv_images, y_images = create_yuv_images(im_batch,56,56)
local x, uv_images = x:type(dtype), uv_images:type(dtype)
local y = uv_images + 0.5
model:evaluate()
local scores = model:forward(x)
local val_loss = crit:forward(scores, y)
print(val_loss)
uv_op_load = model.output - 0.5
for i = 1,4 do
    size = 64
    itorch.image({image.scale(y2rgb(image.rgb2y(im_batch[i])),size,size),
                  image.scale(image.yuv2rgb(torch.cat(y_images[i],uv_op_load[i],1)),size,size),
                  image.scale(image.yuv2rgb(torch.cat(y_images[i],uv_images[i],1)),size,size)})
end

-- %%
for i = 1,8 do
    size = 64
    itorch.image({image.scale(y2rgb(image.rgb2y(im_batch[i])),size,size),
                  image.scale(image.yuv2rgb(torch.cat(y_images[i],uv_op_load[i],1)),size,size),
                  image.scale(image.yuv2rgb(torch.cat(y_images[i],uv_images[i],1)),size,size)})
end

-- %%
checkpoint_1 = torch.load('../../results/checkpoint_40.t7')
model = checkpoint_1.model
local crit = nn.MSECriterion():type(dtype)
opt = checkpoint_1.opt
model:evaluate()

local im_batch = get_validation_batch(opt.batch_size)
local x = torch.Tensor(im_batch:size()[1],im_batch:size()[2],224,224)

for i=1,im_batch:size()[1] do
    x[i] = preprocess(im_batch[i])
end
local uv_images, y_images = create_yuv_images(im_batch,56,56)
local x, uv_images = x:type(dtype), uv_images:type(dtype)
local y = uv_images + 0.5
model:evaluate()
local scores = model:forward(x)
local val_loss = crit:forward(scores, y)
print(val_loss)
uv_op_load = model.output - 0.5
for i = 1,2 do
    size = 64
    itorch.image({image.scale(y2rgb(image.rgb2y(im_batch[i])),size,size),
                  image.scale(image.yuv2rgb(torch.cat(y_images[i],uv_op_load[i],1)),size,size),
                  image.scale(image.yuv2rgb(torch.cat(y_images[i],uv_images[i],1)),size,size)})
end

-- %%
checkpoint_1 = torch.load('../../results/checkpoint_50.t7')
model = checkpoint_1.model
local crit = nn.MSECriterion():type(dtype)
opt = checkpoint_1.opt

local im_batch = get_validation_batch(opt.batch_size)
local x = torch.Tensor(im_batch:size()[1],im_batch:size()[2],224,224)

for i=1,im_batch:size()[1] do
    x[i] = preprocess(im_batch[i])
end
local uv_images, y_images = create_yuv_images(im_batch,56,56)
local x, uv_images = x:type(dtype), uv_images:type(dtype)
local y = uv_images + 0.5
model:evaluate()
local scores = model:forward(x)
local val_loss = crit:forward(scores, y)
print(val_loss)
uv_op_load = model.output - 0.5
for i = 1,2 do
    size = 64
    itorch.image({image.scale(y2rgb(image.rgb2y(im_batch[i])),size,size),
                  image.scale(image.yuv2rgb(torch.cat(y_images[i],uv_op_load[i],1)),size,size),
                  image.scale(image.yuv2rgb(torch.cat(y_images[i],uv_images[i],1)),size,size)})
end

-- %%
checkpoint_1 = torch.load('../../results/checkpoint_50.t7')
model = checkpoint_1.model
local crit = nn.MSECriterion():type(dtype)
opt = checkpoint_1.opt
model:evaluate()

local im_batch = get_validation_batch(opt.batch_size)
local x = torch.Tensor(im_batch:size()[1],im_batch:size()[2],224,224)

for i=1,im_batch:size()[1] do
    x[i] = preprocess(im_batch[i])
end
local uv_images, y_images = create_yuv_images(im_batch,56,56)
local x, uv_images = x:type(dtype), uv_images:type(dtype)
local y = uv_images + 0.5
model:evaluate()
local scores = model:forward(x)
local val_loss = crit:forward(scores, y)
print(val_loss)
uv_op_load = model.output - 0.5
for i = 1,2 do
    size = 64
    itorch.image({image.scale(y2rgb(image.rgb2y(im_batch[i])),size,size),
                  image.scale(image.yuv2rgb(torch.cat(y_images[i],uv_op_load[i],1)),size,size),
                  image.scale(image.yuv2rgb(torch.cat(y_images[i],uv_images[i],1)),size,size)})
end
