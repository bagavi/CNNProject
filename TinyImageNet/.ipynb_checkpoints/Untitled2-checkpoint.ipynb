-- %%
require 'image'
-- Out:
-- {
--   yuv2rgb : function: 0x40b076b8
--   savePNG : function: 0x40b06e20
--   savePGM : function: 0x40b06d18
--   hflip : function: 0x40e42550
--   fabio : function: 0x40e42690
--   convolve : function: 0x40e425b0
--   supported_filetypes :
--     {
--       pgm :
--         {
--           loader : function: 0x40b06cd0
--           saver : function: 0x40b06d18
--         }
--       JPEG :
--         {
--           loader : function: 0x40b06ec8
--           saver : function: 0x40813328
--         }
--       JPG :
--         {
--           loader : function: 0x40b06ec8
--           saver : function: 0x40813328
--         }
--       jpg :
--         {
--           loader : function: 0x40b06ec8
--           saver : function: 0x40813328
--         }
--       png :
--         {
--           loader : function: 0x40b06d98
--           saver : function: 0x40b06e20
--         }
--       ppm :
--         {
--           loader : function: 0x40b06cd0
--           saver : function: 0x40b06cf8
-- ...

-- %%
size = 112
filename = 'test_image/'
paths.mkdir(filename)
image.save('test_image/test_img.png',image.scale(image.fabio(),size,size))
