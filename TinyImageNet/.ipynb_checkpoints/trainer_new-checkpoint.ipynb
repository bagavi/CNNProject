-- %%
require 'Utils'
require 'Net1'
require 'VGG'

-- %%
file_list = get_file_names();

-- %%
print(#file_list)
-- Out:
-- 10000

-- %%
im_batch = get_image_batch(5)

-- %%
itorch.image(im_batch)
-- Out:
-- Console does not support images

-- %%
uv_images,y_images = create_yuv_images(im_batch,28,28)
print(uv_images:size())
-- Out:
--   5
--   2
--  28
--  28
-- [torch.LongStorage of size 4]

-- %%
itorch.image(torch.cat(y_images,uv_images,2))
-- Out:
-- Console does not support images

-- %%
itorch.image(image.yuv2rgb(torch.cat(y_images[5],uv_images[5],1)))
-- Out:
-- Console does not support images

-- %%
require 'VGG';
require 'nn';
VGG_net = load_VGG();
-- Out:
-- Successfully loaded ../../Data/VGG_caffe/VGG_ILSVRC_16_layers.caffemodel
-- conv1_1: 64 3 3 3
-- conv1_2: 64 64 3 3
-- conv2_1: 128 64 3 3
-- conv2_2: 128 128 3 3
-- conv3_1: 256 128 3 3
-- conv3_2: 256 256 3 3
-- conv3_3: 256 256 3 3
-- conv4_1: 512 256 3 3
-- conv4_2: 512 512 3 3
-- conv4_3: 512 512 3 3
-- conv5_1: 512 512 3 3
-- conv5_2: 512 512 3 3
-- conv5_3: 512 512 3 3
-- fc6: 1 1 25088 4096
-- fc7: 1 1 4096 4096
-- fc8: 1 1 4096 1000

-- %%
-- Defining a loss function
Weight = torch.ones(2,28,28)-- All ones matrix -- Bad coding
criterion = nn.WeightedMSECriterion(Weight)
print('MSEcriterion defined')
-- Out:
-- MSEcriterion defined

-- %%
function create_hypercolumn_dataset_random(num_images, layer_nums)
    local max_count = num_images;
    im_batch = get_image_batch(num_images)
    local count = 1;
    
    local hc_batch = nil;
    local hc_temp = get_VGG_hypercolumns(im_batch[count],VGG_net,layer_nums)
    local hc_size = hc_temp:size();
    hc_batch = hc_temp:reshape(1,hc_size[1], hc_size[2], hc_size[3] );
    
    for count=2,num_images do
        hc_temp = get_VGG_hypercolumns(im_batch[count],VGG_net,layer_nums)
        hc_temp = hc_temp:reshape(1,hc_size[1], hc_size[2], hc_size[3] );
        hc_batch = torch.cat(hc_batch, hc_temp,1)
    end
    return im_batch,hc_batch
    
end

-- %%
local layer_nums = {3,9}
im_batch,hc_batch = create_hypercolumn_dataset_random(5, layer_nums);
hc_size = hc_batch:size()
num_hypercolumns = hc_size[2]
print(num_hypercolumns)
-- Out:
-- 192

-- %%
net = BasicConvNet2();

-- %%
layer_nums = {3,9}
num_images = 8;
decay = 0.95;
for i = 1,20 do
    im_batch,hc_batch = create_hypercolumn_dataset_random(num_images, layer_nums);
    hc_size = hc_batch:size()
    num_hypercolumns = hc_size[2]
    uv_images,y_images = create_yuv_images(im_batch,28,28)
    lr = 0.1;
    for j = 1,10 do
        loss = criterion:forward(net:forward(hc_batch), uv_images+0.5)
        print("batch: ".. i .. ") iter:" .. j .. " " .. loss)
        net:zeroGradParameters()
        net:backward(hc_batch, criterion:backward(net.output, uv_images+0.5))
        lr = lr*decay
        net:updateParameters(lr)
    end
end
-- Out:
-- batch: 1) iter:1 0.008244907011902
-- batch: 1) iter:2 0.0052915933921362
-- batch: 1) iter:3 0.0045434281053843
-- batch: 1) iter:4 0.004160695140786
-- batch: 1) iter:5 0.0038835425644672
-- batch: 1) iter:6 0.0036584313443847
-- batch: 1) iter:7 0.0034688510923285
-- batch: 1) iter:8 0.00330699673623
-- batch: 1) iter:9 0.0031675934514854
-- batch: 1) iter:10 0.0030466469786932
-- batch: 2) iter:1 0.0045907071881035
-- batch: 2) iter:2 0.0040964787466717
-- batch: 2) iter:3 0.0037726570772932
-- batch: 2) iter:4 0.0035361052776807
-- batch: 2) iter:5 0.0033528253019246
-- batch: 2) iter:6 0.0032060458707708
-- batch: 2) iter:7 0.0030848991715802
-- batch: 2) iter:8 0.0029826216006712
-- batch: 2) iter:9 0.0028949952951808
-- batch: 2) iter:10 0.002819238189259
-- batch: 3) iter:1 0.0030393289535798
-- batch: 3) iter:2 0.0021482107093908
-- batch: 3) iter:3 0.0019778536231709
-- batch: 3) iter:4 0.0019121069164928
-- batch: 3) iter:5 0.001867921855949
-- batch: 3) iter:6 0.0018318434689585
-- batch: 3) iter:7 0.0018007380720228
-- batch: 3) iter:8 0.0017734631283581
-- batch: 3) iter:9 0.0017492634375694
-- batch: 3) iter:10 0.0017276119753259
-- batch: 4) iter:1 0.0018469097681795
-- batch: 4) iter:2 0.0017817077404596
-- batch: 4) iter:3 0.0017433390165954
-- batch: 4) iter:4 0.0017129658322155
-- batch: 4) iter:5 0.0016871618221065
-- batch: 4) iter:6 0.0016647788524141
-- batch: 4) iter:7 0.0016451008860312
-- batch: 4) iter:8 0.001627603695106
-- batch: 4) iter:9 0.0016119214380269
-- batch: 4) iter:10 0.0015977844119598
-- batch: 5) iter:1 0.0023437640822832
-- batch: 5) iter:2 0.0019895137314683
-- batch: 5) iter:3 0.0018976889007126
-- batch: 5) iter:4 0.0018500944241457
-- batch: 5) iter:5 0.0018142953086939
-- batch: 5) iter:6 0.0017839852748351
-- batch: 5) iter:7 0.0017574061774133
-- batch: 5) iter:8 0.0017337663778392
-- batch: 5) iter:9 0.0017125255909604
-- batch: 5) iter:10 0.0016933550831236
-- batch: 6) iter:1 0.0024670347118147
-- batch: 6) iter:2 0.0019324296117622
-- batch: 6) iter:3 0.0017845584118682
-- batch: 6) iter:4 0.0017101814017694
-- batch: 6) iter:5 0.0016572290284558
-- batch: 6) iter:6 0.001614905524329
-- batch: 6) iter:7 0.0015796601213041
-- batch: 6) iter:8 0.0015497505561724
-- batch: 6) iter:9 0.0015240315476117
-- batch: 6) iter:10 0.0015017031060628
-- batch: 7) iter:1 0.0023837771504954
-- batch: 7) iter:2 0.0017543950440828
-- batch: 7) iter:3 0.0015708130866252
-- batch: 7) iter:4 0.0014943351082524
-- batch: 7) iter:5 0.0014498267297787
-- batch: 7) iter:6 0.0014180536852024
-- batch: 7) iter:7 0.0013927276104112
-- batch: 7) iter:8 0.0013713330659746
-- batch: 7) iter:9 0.0013527698781652
-- batch: 7) iter:10 0.0013364396888439
-- batch: 8) iter:1 0.002731458662266
-- batch: 8) iter:2 0.0017652413950928
-- batch: 8) iter:3 0.0015298749900545
-- batch: 8) iter:4 0.0014517484777307
-- batch: 8) iter:5 0.0014107506354292
-- batch: 8) iter:6 0.0013815156006018
-- batch: 8) iter:7 0.0013577746010862
-- batch: 8) iter:8 0.0013375381090856
-- batch: 8) iter:9 0.0013198387416959
-- batch: 8) iter:10 0.0013042220709464
-- batch: 9) iter:1 0.0018149522969832
-- batch: 9) iter:2 0.0016320029187127
-- batch: 9) iter:3 0.0015647893616474
-- batch: 9) iter:4 0.0015221621761941
-- batch: 9) iter:5 0.001489490635517
-- batch: 9) iter:6 0.0014629720129826
-- batch: 9) iter:7 0.0014408678572747
-- batch: 9) iter:8 0.0014221340962312
-- batch: 9) iter:9 0.0014060115312247
-- batch: 9) iter:10 0.0013919862610738
-- batch: 10) iter:1 0.0021213838609607
-- batch: 10) iter:2 0.0019251734516654
-- batch: 10) iter:3 0.0017939488610883
-- batch: 10) iter:4 0.0017012088801369
-- batch: 10) iter:5 0.0016335157735594
-- batch: 10) iter:6 0.0015803109341276
-- batch: 10) iter:7 0.0015371309100375
-- batch: 10) iter:8 0.0015012979412765
-- batch: 10) iter:9 0.001471111427191
-- batch: 10) iter:10 0.0014453879048714
-- batch: 11) iter:1 0.0018804453627749
-- batch: 11) iter:2 0.0014407040061358
-- batch: 11) iter:3 0.0013244933532855
-- batch: 11) iter:4 0.0012729926274539
-- batch: 11) iter:5 0.0012402922208168
-- batch: 11) iter:6 0.0012158627424369
-- batch: 11) iter:7 0.0011964566989677
-- batch: 11) iter:8 0.0011805082063277
-- batch: 11) iter:9 0.0011671536146172
-- batch: 11) iter:10 0.0011558235060608
-- batch: 12) iter:1 0.0048017920104409
-- batch: 12) iter:2 0.0033600091322697
-- batch: 12) iter:3 0.0027706721337651
-- batch: 12) iter:4 0.0024361018990786
-- batch: 12) iter:5 0.0022109930490192
-- batch: 12) iter:6 0.0020471284103497
-- batch: 12) iter:7 0.0019208854534216
-- batch: 12) iter:8 0.0018199904421756
-- batch: 12) iter:9 0.0017377462422942
-- batch: 12) iter:10 0.0016694158345715
-- batch: 13) iter:1 0.003400339346037
-- batch: 13) iter:2 0.001886503239189
-- batch: 13) iter:3 0.0015490790659855
-- batch: 13) iter:4 0.0014326714383724
-- batch: 13) iter:5 0.0013692889070914
-- batch: 13) iter:6 0.0013249275647854
-- batch: 13) iter:7 0.0012906454579679
-- batch: 13) iter:8 0.001263072442305
-- batch: 13) iter:9 0.0012403304519155
-- batch: 13) iter:10 0.0012212394502655
-- batch: 14) iter:1 0.0020448136187978
-- batch: 14) iter:2 0.0015054451631927
-- batch: 14) iter:3 0.0013362173158182
-- batch: 14) iter:4 0.0012544807784774
-- batch: 14) iter:5 0.0012018561943001
-- batch: 14) iter:6 0.0011630699065679
-- batch: 14) iter:7 0.0011327050957725
-- batch: 14) iter:8 0.001108242942942
-- batch: 14) iter:9 0.0010880866073495
-- batch: 14) iter:10 0.0010712382163223
-- batch: 15) iter:1 0.0014913332257468
-- batch: 15) iter:2 0.0013728731419676
-- batch: 15) iter:3 0.0013346480708285
-- batch: 15) iter:4 0.0013128144961028
-- batch: 15) iter:5 0.0012958823157811
-- batch: 15) iter:6 0.0012813534010034
-- batch: 15) iter:7 0.0012685029451214
-- batch: 15) iter:8 0.0012569786772075
-- batch: 15) iter:9 0.0012465602807961
-- batch: 15) iter:10 0.0012370991091438
-- batch: 16) iter:1 0.0026060648429703
-- batch: 16) iter:2 0.0015623036798415
-- batch: 16) iter:3 0.0012942845054398
-- batch: 16) iter:4 0.0011852723675752
-- batch: 16) iter:5 0.0011212588794759
-- batch: 16) iter:6 0.0010762082942116
-- batch: 16) iter:7 0.0010419966862947
-- batch: 16) iter:8 0.0010151151987583
-- batch: 16) iter:9 0.0009934954108648
-- batch: 16) iter:10 0.00097579339067221
-- batch: 17) iter:1 0.0024069780538966
-- batch: 17) iter:2 0.0016786968817462
-- batch: 17) iter:3 0.0014694311886382
-- batch: 17) iter:4 0.0013797565723573
-- batch: 17) iter:5 0.0013253212613244
-- batch: 17) iter:6 0.0012854486852585
-- batch: 17) iter:7 0.0012536532890539
-- batch: 17) iter:8 0.0012273523820515
-- batch: 17) iter:9 0.0012052265509601
-- batch: 17) iter:10 0.0011863475526244
-- batch: 18) iter:1 0.0020932782713703
-- batch: 18) iter:2 0.0014790007747483
-- batch: 18) iter:3 0.0012893772047128
-- batch: 18) iter:4 0.001209813272153
-- batch: 18) iter:5 0.0011656032396866
-- batch: 18) iter:6 0.0011355853838036
-- batch: 18) iter:7 0.001112858328126
-- batch: 18) iter:8 0.0010945615028316
-- batch: 18) iter:9 0.0010793223270608
-- batch: 18) iter:10 0.0010663416255965
-- batch: 19) iter:1 0.0025033119473624
-- batch: 19) iter:2 0.0015975766119974
-- batch: 19) iter:3 0.0012986563046038
-- batch: 19) iter:4 0.0011742324598665
-- batch: 19) iter:5 0.0011096512324842
-- batch: 19) iter:6 0.0010691131239472
-- batch: 19) iter:7 0.0010399093114957
-- batch: 19) iter:8 0.0010170931264778
-- batch: 19) iter:9 0.00099833749861381
-- batch: 19) iter:10 0.00098245845274947
-- batch: 20) iter:1 0.0017779287297557
-- batch: 20) iter:2 0.0013814790772803
-- batch: 20) iter:3 0.0012539319733882
-- batch: 20) iter:4 0.0011909031833672
-- batch: 20) iter:5 0.001149501435593
-- batch: 20) iter:6 0.0011184664983913
-- batch: 20) iter:7 0.0010938970391213
-- batch: 20) iter:8 0.0010739252811425
-- batch: 20) iter:9 0.0010573268030449
-- batch: 20) iter:10 0.0010433537555812

-- %%
uv_op = net.output-0.5

-- %%
itorch.image(torch.cat(y_images,uv_op,2))
-- Out:
-- Console does not support images

-- %%
itorch.image(image.scale(image.yuv2rgb(torch.cat(y_images[3],uv_op[3],1)),224,224))
-- Out:
-- Console does not support images

-- %%
itorch.image(image.scale(im_batch[3],224,224))
-- Out:
-- Console does not support images

-- %%
function create_hypercolumn_dataset_random_bw(num_images, layer_nums)
    local max_count = num_images;
    im_batch = get_image_batch(num_images)
    
    local count = 1;
    y_temp = image.rgb2y(im_batch[count])
    im_y = torch.cat(y_temp,y_temp,1);
    im_y = torch.cat(im_y,y_temp,1);
    local hc_batch = nil;
    local hc_temp = get_VGG_hypercolumns(im_y,VGG_net,layer_nums)
    hc_size = hc_temp:size();
    hc_batch = hc_temp:reshape(1,hc_size[1], hc_size[2], hc_size[3] );
    
    for count=2,num_images do

        y_temp = image.rgb2y(im_batch[count])
        im_y = torch.cat(y_temp,y_temp,1);
        im_y = torch.cat(im_y,y_temp,1);

        hc_temp = get_VGG_hypercolumns(im_y,VGG_net,layer_nums)
        hc_temp = hc_temp:reshape(1,hc_size[1], hc_size[2], hc_size[3] );
        hc_batch = torch.cat(hc_batch, hc_temp,1)
    end
    return im_batch,hc_batch
    
end

-- %%
local layer_nums = {3,9}
local num_images = 8;
val_im_batch,val_hc_batch = create_hypercolumn_dataset_random_bw(num_images, layer_nums)
-- val_im_batch,val_hc_batch = create_hypercolumn_dataset_random(num_images, layer_nums);
hc_size = val_hc_batch:size()
num_hypercolumns = hc_size[2]
uv_images,y_images = create_yuv_images(val_im_batch,28,28)
net:forward(val_hc_batch);
val_uv = net.output -0.5;

-- %%
local num_images = 8;
for iter=1,num_images do
    itorch.image(image.scale(image.yuv2rgb(torch.cat(y_images[iter],val_uv[iter],1)),224,224))
    itorch.image(image.scale(im_batch[iter],224,224))
end
-- Out:
-- Console does not support images
-- Console does not support images
-- Console does not support images
-- Console does not support images
-- Console does not support images
-- Console does not support images
-- Console does not support images
-- Console does not support images
-- Console does not support images
-- Console does not support images
-- Console does not support images
-- Console does not support images
-- Console does not support images
-- Console does not support images
-- Console does not support images
-- Console does not support images

-- %%
local layer_nums = {3,9}
local num_images = 8;
-- val_im_batch,val_hc_batch = create_hypercolumn_dataset_random_bw(num_images, layer_nums)
val_im_batch,val_hc_batch = create_hypercolumn_dataset_random(num_images, layer_nums);
hc_size = val_hc_batch:size()
num_hypercolumns = hc_size[2]
uv_images,y_images = create_yuv_images(val_im_batch,28,28)
net:forward(val_hc_batch);
val_uv = net.output -0.5;

-- %%
local num_images = 8;
for iter=1,num_images do
    itorch.image(image.scale(image.yuv2rgb(torch.cat(y_images[iter],val_uv[iter],1)),224,224))
    itorch.image(image.scale(im_batch[iter],224,224))
end
-- Out:
-- Console does not support images
-- Console does not support images
-- Console does not support images
-- Console does not support images
-- Console does not support images
-- Console does not support images
-- Console does not support images
-- Console does not support images
-- Console does not support images
-- Console does not support images
-- Console does not support images
-- Console does not support images
-- Console does not support images
-- Console does not support images
-- Console does not support images
-- Console does not support images
