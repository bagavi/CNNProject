-- %%
require 'VGG';

-- %%
VGG_net = load_VGG();
-- Out:
-- Successfully loaded ../../Data/VGG_caffe/VGG_ILSVRC_16_layers.caffemodel
-- conv1_1: 64 3 3 3
-- conv1_2: 64 64 3 3
-- conv2_1: 128 64 3 3
-- conv2_2: 128 128 3 3
-- conv3_1: 256 128 3 3
-- conv3_2: 256 256 3 3
-- conv3_3: 256 256 3 3
-- conv4_1: 512 256 3 3
-- conv4_2: 512 512 3 3
-- conv4_3: 512 512 3 3
-- conv5_1: 512 512 3 3
-- conv5_2: 512 512 3 3
-- conv5_3: 512 512 3 3
-- fc6: 1 1 25088 4096
-- fc7: 1 1 4096 4096
-- fc8: 1 1 4096 1000

-- %%
image_name = '../../Data/tiny-imagenet-200/test/images/test_4.JPEG'
im1 = image.load(image_name) -- loading the image
itorch.image(im1);
-- Out:
-- Console does not support images

-- %%
p_img = preprocess(im1)
itorch.image(p_img);
-- Out:
-- Console does not support images

-- %%
top_classes = VGG_forward_test(im1,VGG_net);
--prob_1,classes_1 = net:forward(p_img):view(-1):sort(true)
--print(prob)
--classes5 = VGG_forward(im1,VGG_net)
print(top_classes);
-- Out:
-- {
--   1 : albatross, mollymawk
--   2 : grey whale, gray whale, devilfish, Eschrichtius gibbosus, Eschrichtius robustus
--   3 : red-breasted merganser, Mergus serrator
--   4 : killer whale, killer, orca, grampus, sea wolf, Orcinus orca
--   5 : Japanese spaniel
-- }
